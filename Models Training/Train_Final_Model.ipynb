# %%
import numpy as np

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.xception import preprocess_input
from keras.applications.inception_v3 import preprocess_input
from keras.models import load_model
from tensorflow.keras.models import load_model

# %%
img = load_img('cupcakes.jpg', target_size=(200, 200))
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FF330D1AE20>

# %%
# convert image in to array
x = np.array(img)
X = np.array([x])

X = preprocess_input(X)

# %%
X.shape
# Out:
# (1, 200, 200, 3)

# %%
model = keras.models.load_model('best_model_101class.hdf5')

# %%
preds = model.predict(X)
preds
# Out:
# array([[1.29762953e-02, 2.34675957e-04, 2.91665108e-03, 1.95029425e-03,
#         9.33368411e-03, 6.44024462e-04, 4.19430342e-03, 6.41488587e-04,
#         6.65251352e-03, 6.12681499e-04, 1.65213773e-03, 3.42111714e-04,
#         7.20987469e-03, 3.88595765e-03, 5.58371842e-03, 1.82568457e-03,
#         2.04751175e-03, 7.86075089e-03, 5.41764137e-04, 5.36040519e-04,
#         9.72428476e-04, 8.42839759e-03, 1.06985215e-02, 2.31020129e-03,
#         9.48570902e-04, 2.91924598e-03, 4.61930316e-03, 2.71753035e-03,
#         6.36251923e-03, 4.41272080e-01, 8.61629844e-03, 1.56949177e-01,
#         3.18694394e-03, 1.27726118e-03, 6.00993633e-03, 1.32853363e-03,
#         9.46367439e-03, 6.86175947e-04, 6.19916013e-04, 4.82591987e-03,
#         1.70854188e-03, 5.60524582e-04, 1.57560606e-03, 3.83679522e-04,
#         2.06224548e-04, 4.68629133e-03, 1.37416448e-03, 5.24639792e-04,
#         8.17085907e-04, 2.46477174e-03, 6.07815280e-04, 6.64177176e-04,
#         6.22132793e-04, 1.90059524e-02, 2.62103626e-04, 5.59869129e-03,
#         2.73061194e-03, 2.50468729e-03, 1.55052962e-02, 3.16729333e-04,
#         5.23353519e-04, 2.26926641e-03, 4.71758831e-04, 6.25121370e-02,
#         9.58325109e-04, 2.57870322e-03, 6.28841110e-04, 9.97899449e-04,
#         1.76105481e-02, 3.36312363e-03, 3.63416220e-05, 3.15077457e-04,
#         1.79226510e-02, 4.02443344e-03, 6.59198035e-04, 1.34619462e-04,
#         3.70615424e-04, 3.60913051e-04, 2.74785067e-04, 5.87695336e-04,
#         2.27699149e-03, 7.76826229e-04, 1.14348647e-03, 1.26032829e-02,
#         7.64909957e-04, 1.95000507e-03, 4.51388536e-03, 1.12138502e-03,
#         1.99627277e-04, 3.16110410e-04, 1.37548210e-04, 1.77940368e-04,
#         5.03355521e-04, 4.68660408e-04, 2.09665895e-02, 1.27266338e-02,
#         9.04930814e-04, 9.33878066e-04, 2.01443816e-03, 6.76438725e-03,
#         4.16031806e-03]], dtype=float32)

# %%
classes = ['apple_pie',
 'baby_back_ribs',
 'baklava',
 'beef_carpaccio',
 'beef_tartare',
 'beet_salad',
 'beignets',
 'bibimbap',
 'bread_pudding',
 'breakfast_burrito',
 'bruschetta',
 'caesar_salad',
 'cannoli',
 'caprese_salad',
 'carrot_cake',
 'ceviche',
 'cheese_plate',
 'cheesecake',
 'chicken_curry',
 'chicken_quesadilla',
 'chicken_wings',
 'chocolate_cake',
 'chocolate_mousse',
 'churros',
 'clam_chowder',
 'club_sandwich',
 'crab_cakes',
 'creme_brulee',
 'croque_madame',
 'cup_cakes','deviled_eggs',
 'donuts',
 'dumplings',
 'edamame',
 'eggs_benedict',
 'escargots',
 'falafel',
 'filet_mignon',
 'fish_and_chips',
 'foie_gras',
 'french_fries',
 'french_onion_soup',
 'french_toast',
 'fried_calamari',
 'fried_rice',
 'frozen_yogurt',
 'garlic_bread',
 'gnocchi',
 'greek_salad',
 'grilled_cheese_sandwich',
 'grilled_salmon',
 'guacamole',
 'gyoza',
 'hamburger',
 'hot_and_sour_soup',
 'hot_dog','huevos_rancheros',
 'hummus',
 'ice_cream',
 'lasagna',
 'lobster_bisque',
 'lobster_roll_sandwich',
 'macaroni_and_cheese',
 'macarons',
 'miso_soup',
 'mussels',
 'nachos',
 'omelette',
 'onion_rings',
 'oysters',
 'pad_thai',
 'paella',
 'pancakes',
 'panna_cotta',
 'peking_duck',
 'pho',
 'pizza',
 'pork_chop',
 'poutine',
 'prime_rib',
 'pulled_pork_sandwich',
 'ramen',
 'ravioli',
 'red_velvet_cake',
 'risotto',
 'samosa',
 'sashimi',
 'scallops',
 'seaweed_salad',
 'shrimp_and_grits',
 'spaghetti_bolognese',
 'spaghetti_carbonara',
 'spring_rolls',
 'steak',
 'strawberry_shortcake',
 'sushi',
 'tacos',
 'takoyaki',
 'tiramisu',
 'tuna_tartare',
 'waffles']

# %%
#combine labels and actual predections 
dict(zip(classes, preds[0]))
# Out:
# {'apple_pie': 0.012976295,
#  'baby_back_ribs': 0.00023467596,
#  'baklava': 0.002916651,
#  'beef_carpaccio': 0.0019502942,
#  'beef_tartare': 0.009333684,
#  'beet_salad': 0.00064402446,
#  'beignets': 0.0041943034,
#  'bibimbap': 0.0006414886,
#  'bread_pudding': 0.0066525135,
#  'breakfast_burrito': 0.0006126815,
#  'bruschetta': 0.0016521377,
#  'caesar_salad': 0.0003421117,
#  'cannoli': 0.0072098747,
#  'caprese_salad': 0.0038859576,
#  'carrot_cake': 0.0055837184,
#  'ceviche': 0.0018256846,
#  'cheese_plate': 0.0020475117,
#  'cheesecake': 0.007860751,
#  'chicken_curry': 0.00054176414,
#  'chicken_quesadilla': 0.0005360405,
#  'chicken_wings': 0.0009724285,
#  'chocolate_cake': 0.008428398,
#  'chocolate_mousse': 0.0106985215,
#  'churros': 0.0023102013,
#  'clam_chowder': 0.0009485709,
#  'club_sandwich': 0.002919246,
#  'crab_cakes': 0.004619303,
#  'creme_brulee': 0.0027175304,
#  'croque_madame': 0.006362519,
#  'cup_cakes': 0.44127208,
#  'deviled_eggs': 0.008616298,
#  'donuts': 0.15694918,
#  'dumplings': 0.003186944,
#  'edamame': 0.0012772612,
#  'eggs_benedict': 0.0060099363,
#  'escargots': 0.0013285336,
#  'falafel': 0.009463674,
#  'filet_mignon': 0.00068617595,
#  'fish_and_chips': 0.000619916,
#  'foie_gras': 0.00482592,
#  'french_fries': 0.0017085419,
#  'french_onion_soup': 0.0005605246,
#  'french_toast': 0.0015756061,
#  'fried_calamari': 0.00038367952,
#  'fried_rice': 0.00020622455,
#  'frozen_yogurt': 0.0046862913,
#  'garlic_bread': 0.0013741645,
#  'gnocchi': 0.0005246398,
#  'greek_salad': 0.0008170859,
#  'grilled_cheese_sandwich': 0.0024647717,
#  'grilled_salmon': 0.0006078153,
#  'guacamole': 0.0006641772,
#  'gyoza': 0.0006221328,
#  'hamburger': 0.019005952,
#  'hot_and_sour_soup': 0.00026210363,
#  'hot_dog': 0.0055986913,
#  'huevos_rancheros': 0.002730612,
#  'hummus': 0.0025046873,
#  'ice_cream': 0.015505296,
#  'lasagna': 0.00031672933,
#  'lobster_bisque': 0.0005233535,
#  'lobster_roll_sandwich': 0.0022692664,
#  'macaroni_and_cheese': 0.00047175883,
#  'macarons': 0.06251214,
#  'miso_soup': 0.0009583251,
#  'mussels': 0.0025787032,
#  'nachos': 0.0006288411,
#  'omelette': 0.0009978994,
#  'onion_rings': 0.017610548,
#  'oysters': 0.0033631236,
#  'pad_thai': 3.6341622e-05,
#  'paella': 0.00031507746,
#  'pancakes': 0.017922651,
#  'panna_cotta': 0.0040244334,
#  'peking_duck': 0.00065919803,
#  'pho': 0.00013461946,
#  'pizza': 0.00037061542,
#  'pork_chop': 0.00036091305,
#  'poutine': 0.00027478507,
#  'prime_rib': 0.00058769534,
#  'pulled_pork_sandwich': 0.0022769915,
#  'ramen': 0.00077682623,
#  'ravioli': 0.0011434865,
#  'red_velvet_cake': 0.012603283,
#  'risotto': 0.00076490996,
#  'samosa': 0.0019500051,
#  'sashimi': 0.0045138854,
#  'scallops': 0.001121385,
#  'seaweed_salad': 0.00019962728,
#  'shrimp_and_grits': 0.0003161104,
#  'spaghetti_bolognese': 0.00013754821,
#  'spaghetti_carbonara': 0.00017794037,
#  'spring_rolls': 0.0005033555,
#  'steak': 0.0004686604,
#  'strawberry_shortcake': 0.02096659,
#  'sushi': 0.012726634,
#  'tacos': 0.0009049308,
#  'takoyaki': 0.00093387807,
#  'tiramisu': 0.0020144382,
#  'tuna_tartare': 0.0067643872,
#  'waffles': 0.004160318}

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)

tflite_model = converter.convert()

#save the model
with open('Best_restaurant_to_serve.tflite', 'wb') as f_out:
    f_out.write(tflite_model)
# Out:
# 2021-12-14 14:25:55.947151: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /var/folders/5s/020k6xms3yn8kwdq_4y_8zl00000gn/T/tmpx2xec9uc/assets
# 2021-12-14 14:30:55.007838: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:363] Ignored output_format.
# 2021-12-14 14:30:55.007901: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:366] Ignored drop_control_dependency.
# 2021-12-14 14:30:55.009326: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /var/folders/5s/020k6xms3yn8kwdq_4y_8zl00000gn/T/tmpx2xec9uc
# 2021-12-14 14:30:55.175954: I tensorflow/cc/saved_model/reader.cc:107] Reading meta graph with tags { serve }
# 2021-12-14 14:30:55.175991: I tensorflow/cc/saved_model/reader.cc:148] Reading SavedModel debug info (if present) from: /var/folders/5s/020k6xms3yn8kwdq_4y_8zl00000gn/T/tmpx2xec9uc
# 2021-12-14 14:30:56.333906: I tensorflow/cc/saved_model/loader.cc:210] Restoring SavedModel bundle.
# 2021-12-14 14:30:58.971867: I tensorflow/cc/saved_model/loader.cc:194] Running initialization op on SavedModel bundle at path: /var/folders/5s/020k6xms3yn8kwdq_4y_8zl00000gn/T/tmpx2xec9uc
# 2021-12-14 14:30:59.962422: I tensorflow/cc/saved_model/loader.cc:283] SavedModel load for tags { serve }; Status: success: OK. Took 4953117 microseconds.
# 2021-12-14 14:31:02.115868: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:237] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded

# %% [markdown]
# # Restart Kernal

# %%
# !pip install keras-image-helper
# Out:
# Requirement already satisfied: keras-image-helper in /Users/macbookpro/opt/anaconda3/lib/python3.8/site-packages (0.0.1)
# Requirement already satisfied: pillow in /Users/macbookpro/opt/anaconda3/lib/python3.8/site-packages (from keras-image-helper) (8.2.0)
# Requirement already satisfied: numpy in /Users/macbookpro/opt/anaconda3/lib/python3.8/site-packages (from keras-image-helper) (1.21.4)

# %%
# !pip install --extra-index-url https://google-coral.github.io/py-repo/ tflite_runtime
# Out:
# Looking in indexes: https://pypi.org/simple, https://google-coral.github.io/py-repo/
# Requirement already satisfied: tflite_runtime in /Users/macbookpro/opt/anaconda3/lib/python3.8/site-packages (2.5.0.post1)
# Requirement already satisfied: numpy>=1.16.0 in /Users/macbookpro/opt/anaconda3/lib/python3.8/site-packages (from tflite_runtime) (1.21.4)

# %%
#import tensorflow.lite as tflite
import tflite_runtime.interpreter as tflite
from keras_image_helper import create_preprocessor

# %%
interpreter = tflite.Interpreter(model_path='Best_restaurant_to_serve.tflite')
interpreter.allocate_tensors()

input_index = interpreter.get_input_details()[0]['index']
output_index = interpreter.get_output_details()[0]['index']

# %%
preprocessor = create_preprocessor('xception', target_size=(200, 200))

# %%
url = 'https://upload.wikimedia.org/wikipedia/commons/a/a5/Cars_Cupcakes_%284725761659%29.jpg'
url
# Out:
# 'https://upload.wikimedia.org/wikipedia/commons/a/a5/Cars_Cupcakes_%284725761659%29.jpg'

# %%
X = preprocessor.from_url(url)

# %%
interpreter.set_tensor(input_index, X) # put input in the interpreter 
interpreter.invoke() #model work 
preds = interpreter.get_tensor(output_index) #get or fetch output 
preds
# Out:
# array([[3.1441594e-03, 1.4759937e-05, 8.6689054e-04, 5.4019893e-05,
#         7.9311128e-04, 2.9954321e-05, 2.4838655e-04, 1.6941107e-04,
#         1.5829515e-03, 3.3443943e-05, 1.6407190e-04, 2.0650285e-05,
#         1.9075202e-03, 5.9567188e-04, 1.5080664e-03, 4.8155786e-04,
#         1.3630834e-03, 3.0733556e-03, 1.6234908e-05, 5.0448158e-05,
#         1.6828877e-05, 4.1358611e-03, 3.7516747e-03, 4.8047409e-04,
#         1.3811192e-04, 1.4375318e-04, 5.6078879e-04, 1.1974879e-03,
#         1.7536872e-03, 8.5822171e-01, 3.0462879e-03, 7.9145385e-03,
#         1.2386095e-03, 2.1567799e-05, 1.0388187e-03, 2.7895492e-04,
#         1.5260307e-03, 8.4047599e-05, 2.0423584e-05, 8.9058647e-04,
#         1.1362490e-04, 1.1925390e-04, 2.1476617e-04, 4.6521360e-05,
#         1.7009545e-05, 4.5362639e-04, 1.8751792e-04, 2.6854566e-05,
#         8.4400213e-05, 4.9797597e-04, 4.9535003e-05, 5.0494651e-05,
#         1.6207968e-04, 2.1048239e-03, 8.2731094e-06, 8.4032526e-04,
#         1.4054345e-04, 7.0685119e-04, 4.6390267e-03, 5.4880467e-05,
#         1.4058755e-04, 7.7699377e-05, 9.6838245e-05, 5.4460168e-02,
#         2.2686490e-04, 2.6808828e-04, 3.6241170e-05, 6.2895691e-05,
#         9.9595671e-04, 4.3010931e-03, 1.0376879e-06, 1.0509431e-05,
#         2.2336929e-03, 2.4573624e-03, 4.7692531e-05, 7.8909979e-06,
#         3.9630158e-05, 2.2944860e-05, 9.7472048e-06, 9.9762736e-05,
#         2.5027953e-04, 1.6769097e-04, 9.1322370e-05, 5.6958790e-03,
#         6.9381436e-05, 1.6632190e-04, 1.2445073e-03, 3.3309998e-04,
#         5.6211534e-06, 3.4091303e-05, 8.6217115e-06, 1.6764036e-05,
#         6.0183018e-05, 7.3153547e-05, 4.9044448e-03, 4.6687233e-03,
#         5.5073044e-05, 1.2393575e-04, 9.1035117e-04, 2.7540961e-04,
#         2.1521754e-03]], dtype=float32)

# %%
classes = ['apple_pie',
 'baby_back_ribs',
 'baklava',
 'beef_carpaccio',
 'beef_tartare',
 'beet_salad',
 'beignets',
 'bibimbap',
 'bread_pudding',
 'breakfast_burrito',
 'bruschetta',
 'caesar_salad',
 'cannoli',
 'caprese_salad',
 'carrot_cake',
 'ceviche',
 'cheese_plate',
 'cheesecake',
 'chicken_curry',
 'chicken_quesadilla',
 'chicken_wings',
 'chocolate_cake',
 'chocolate_mousse',
 'churros',
 'clam_chowder',
 'club_sandwich',
 'crab_cakes',
 'creme_brulee',
 'croque_madame',
 'cup_cakes','deviled_eggs',
 'donuts',
 'dumplings',
 'edamame',
 'eggs_benedict',
 'escargots',
 'falafel',
 'filet_mignon',
 'fish_and_chips',
 'foie_gras',
 'french_fries',
 'french_onion_soup',
 'french_toast',
 'fried_calamari',
 'fried_rice',
 'frozen_yogurt',
 'garlic_bread',
 'gnocchi',
 'greek_salad',
 'grilled_cheese_sandwich',
 'grilled_salmon',
 'guacamole',
 'gyoza',
 'hamburger',
 'hot_and_sour_soup',
 'hot_dog','huevos_rancheros',
 'hummus',
 'ice_cream',
 'lasagna',
 'lobster_bisque',
 'lobster_roll_sandwich',
 'macaroni_and_cheese',
 'macarons',
 'miso_soup',
 'mussels',
 'nachos',
 'omelette',
 'onion_rings',
 'oysters',
 'pad_thai',
 'paella',
 'pancakes',
 'panna_cotta',
 'peking_duck',
 'pho',
 'pizza',
 'pork_chop',
 'poutine',
 'prime_rib',
 'pulled_pork_sandwich',
 'ramen',
 'ravioli',
 'red_velvet_cake',
 'risotto',
 'samosa',
 'sashimi',
 'scallops',
 'seaweed_salad',
 'shrimp_and_grits',
 'spaghetti_bolognese',
 'spaghetti_carbonara',
 'spring_rolls',
 'steak',
 'strawberry_shortcake',
 'sushi',
 'tacos',
 'takoyaki',
 'tiramisu',
 'tuna_tartare',
 'waffles'
]

dict(zip(classes, preds[0]))
# Out:
# {'apple_pie': 0.0031441594,
#  'baby_back_ribs': 1.4759937e-05,
#  'baklava': 0.00086689054,
#  'beef_carpaccio': 5.4019893e-05,
#  'beef_tartare': 0.0007931113,
#  'beet_salad': 2.995432e-05,
#  'beignets': 0.00024838655,
#  'bibimbap': 0.00016941107,
#  'bread_pudding': 0.0015829515,
#  'breakfast_burrito': 3.3443943e-05,
#  'bruschetta': 0.0001640719,
#  'caesar_salad': 2.0650285e-05,
#  'cannoli': 0.0019075202,
#  'caprese_salad': 0.0005956719,
#  'carrot_cake': 0.0015080664,
#  'ceviche': 0.00048155786,
#  'cheese_plate': 0.0013630834,
#  'cheesecake': 0.0030733556,
#  'chicken_curry': 1.6234908e-05,
#  'chicken_quesadilla': 5.0448158e-05,
#  'chicken_wings': 1.6828877e-05,
#  'chocolate_cake': 0.004135861,
#  'chocolate_mousse': 0.0037516747,
#  'churros': 0.0004804741,
#  'clam_chowder': 0.00013811192,
#  'club_sandwich': 0.00014375318,
#  'crab_cakes': 0.0005607888,
#  'creme_brulee': 0.0011974879,
#  'croque_madame': 0.0017536872,
#  'cup_cakes': 0.8582217,
#  'deviled_eggs': 0.003046288,
#  'donuts': 0.0079145385,
#  'dumplings': 0.0012386095,
#  'edamame': 2.15678e-05,
#  'eggs_benedict': 0.0010388187,
#  'escargots': 0.00027895492,
#  'falafel': 0.0015260307,
#  'filet_mignon': 8.40476e-05,
#  'fish_and_chips': 2.0423584e-05,
#  'foie_gras': 0.00089058647,
#  'french_fries': 0.0001136249,
#  'french_onion_soup': 0.0001192539,
#  'french_toast': 0.00021476617,
#  'fried_calamari': 4.652136e-05,
#  'fried_rice': 1.7009545e-05,
#  'frozen_yogurt': 0.0004536264,
#  'garlic_bread': 0.00018751792,
#  'gnocchi': 2.6854566e-05,
#  'greek_salad': 8.440021e-05,
#  'grilled_cheese_sandwich': 0.00049797597,
#  'grilled_salmon': 4.9535003e-05,
#  'guacamole': 5.049465e-05,
#  'gyoza': 0.00016207968,
#  'hamburger': 0.002104824,
#  'hot_and_sour_soup': 8.273109e-06,
#  'hot_dog': 0.00084032526,
#  'huevos_rancheros': 0.00014054345,
#  'hummus': 0.0007068512,
#  'ice_cream': 0.0046390267,
#  'lasagna': 5.4880467e-05,
#  'lobster_bisque': 0.00014058755,
#  'lobster_roll_sandwich': 7.769938e-05,
#  'macaroni_and_cheese': 9.6838245e-05,
#  'macarons': 0.054460168,
#  'miso_soup': 0.0002268649,
#  'mussels': 0.00026808828,
#  'nachos': 3.624117e-05,
#  'omelette': 6.289569e-05,
#  'onion_rings': 0.0009959567,
#  'oysters': 0.004301093,
#  'pad_thai': 1.0376879e-06,
#  'paella': 1.0509431e-05,
#  'pancakes': 0.002233693,
#  'panna_cotta': 0.0024573624,
#  'peking_duck': 4.769253e-05,
#  'pho': 7.890998e-06,
#  'pizza': 3.963016e-05,
#  'pork_chop': 2.294486e-05,
#  'poutine': 9.747205e-06,
#  'prime_rib': 9.9762736e-05,
#  'pulled_pork_sandwich': 0.00025027953,
#  'ramen': 0.00016769097,
#  'ravioli': 9.132237e-05,
#  'red_velvet_cake': 0.005695879,
#  'risotto': 6.9381436e-05,
#  'samosa': 0.0001663219,
#  'sashimi': 0.0012445073,
#  'scallops': 0.00033309998,
#  'seaweed_salad': 5.6211534e-06,
#  'shrimp_and_grits': 3.4091303e-05,
#  'spaghetti_bolognese': 8.6217115e-06,
#  'spaghetti_carbonara': 1.6764036e-05,
#  'spring_rolls': 6.0183018e-05,
#  'steak': 7.315355e-05,
#  'strawberry_shortcake': 0.004904445,
#  'sushi': 0.0046687233,
#  'tacos': 5.5073044e-05,
#  'takoyaki': 0.00012393575,
#  'tiramisu': 0.00091035117,
#  'tuna_tartare': 0.0002754096,
#  'waffles': 0.0021521754}
